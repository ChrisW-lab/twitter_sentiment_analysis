# %% [markdown]
# ### Code to combine polarity experiment results to compare methods

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pol_bow_accs = [0.8080808 , 0.8030303 , 0.80050504, 0.7979798 , 0.79545456,
                0.7929293 , 0.7929293 , 0.790404  , 0.790404  , 0.7828283 ,
                0.7828283 , 0.780303  , 0.780303  , 0.780303  , 0.7777778 ,
                0.7777778 , 0.7752525 , 0.77272725]

# %%
pol_emb_accs = [0.81565654, 0.81060606, 0.8055556 , 0.7979798 , 0.79545456,
                0.79545456, 0.79545456, 0.79545456, 0.7929293 , 0.7929293 ,
                0.7929293 , 0.790404  , 0.790404  , 0.7878788 , 0.7878788 ,
                0.7878788 , 0.78535354, 0.78535354, 0.78535354, 0.78535354,
                0.78535354, 0.7828283 , 0.7828283 , 0.7828283 , 0.7828283 ,
                0.780303  , 0.780303  , 0.780303  , 0.7777778 , 0.7777778 ,
                0.7752525 , 0.7752525 ]

# %%
pol_seq_emb_accs = [0.84343433, 0.84343433, 0.84343433, 0.83838385, 0.8358586 ,
                    0.8358586 , 0.8333333 , 0.8333333 , 0.8308081 , 0.82828283,
                    0.82828283, 0.82828283, 0.82575756, 0.82575756, 0.82575756,
                    0.8207071 , 0.81565654, 0.81313133]

# %%
pol_seq_bow_accs = [0.8181818 , 0.8181818 , 0.81565654, 0.81565654, 0.81313133,
                    0.81060606, 0.81060606, 0.81060606, 0.8080808 , 0.8080808 ,
                    0.8055556 , 0.8055556 , 0.8030303 , 0.80050504, 0.7979798 ,
                    0.79545456]

# %%
sns.set(color_codes=True)
sns.distplot(pol_bow_accs, color='blue', label='BoW', hist=False)
sns.distplot(pol_seq_bow_accs, color='magenta', label='Sequence BoW', hist=False)
sns.distplot(pol_emb_accs, color='red', label='Embeddings', hist=False)
sns.distplot(pol_seq_emb_accs, color='green', label='Sequence embeddings', hist=False)

plt.xlim(0.75, 0.91)
plt.legend(loc=1)
plt.title('Validation accuracy distributions')
plt.xlabel('Validation accuracy (%)')
# Out:
# Text(0.5, 0, 'Validation accuracy (%)')
