# %% [markdown]
# ### Code to combine polarity experiment results to compare methods

# %%
# import dependencies
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# create list of subjectivity BoW experiment maximum accuracies
sub_bow_accs = [0.8076923 , 0.8076923 , 0.80608976, 0.80448717, 0.80448717,
                0.80288464, 0.80288464, 0.80288464, 0.80288464, 0.80288464,
                0.80288464, 0.80128205, 0.80128205, 0.80128205, 0.80128205,
                0.79967946, 0.79967946, 0.79967946, 0.79967946, 0.79967946,
                0.7980769 , 0.79647434, 0.79647434, 0.79647434, 0.79647434,
                0.7948718 , 0.7948718 , 0.7948718 , 0.7948718 , 0.7948718 ,
                0.7948718 , 0.7948718 , 0.7916667 , 0.7852564 ]

# %%
# create list of subjectivity embedding experiment maximum accuracies
sub_emb_accs = [0.8349359 , 0.8317308 , 0.8301282 , 0.8301282 , 0.82852566,
                0.8269231 , 0.8269231 , 0.82532054, 0.82532054, 0.82532054,
                0.82371795, 0.82371795, 0.82371795, 0.82211536, 0.82211536,
                0.82051283, 0.82051283, 0.81891024, 0.81891024, 0.81891024,
                0.8173077 , 0.8173077 , 0.8173077 , 0.8141026 , 0.8125    ,
                0.8125    , 0.8125    , 0.8108974 , 0.80608976, 0.80448717,
                0.80288464, 0.80128205, 0.7916667 , 0.7900641 ]

# %%
# create list of subjectivity sequence embedding experiment maximum accuracies
sub_seq_emb_accs = [0.80128205, 0.80288464, 0.80448717, 0.8076923 , 0.8092949 ,
                    0.8092949 , 0.8092949 , 0.8125    , 0.8125    , 0.8125    ,
                    0.8125    , 0.8141026 , 0.8157051 , 0.8157051 , 0.8157051 ,
                    0.8173077 , 0.81891024, 0.81891024, 0.81891024, 0.81891024,
                    0.81891024, 0.82051283, 0.82211536, 0.82211536, 0.82211536,
                    0.82211536, 0.82211536, 0.82371795, 0.82371795, 0.82371795,
                    0.82532054, 0.82532054, 0.82532054, 0.8269231 , 0.8269231 ,
                    0.8269231 , 0.8269231 , 0.8269231 , 0.82852566, 0.82852566,
                    0.8301282 , 0.8301282 , 0.8301282 , 0.8301282 , 0.8317308 ,
                    0.8333333 , 0.8333333 , 0.84134614]

# %%
# create list of subjectivity sequence BoW experiment maximum accuracies
sub_seq_bow_accs = [0.8141026 , 0.8092949 , 0.8092949 , 0.8076923 , 0.8076923 ,
                    0.80608976, 0.80448717, 0.80448717, 0.80288464, 0.80288464,
                    0.80128205, 0.80128205, 0.80128205, 0.80128205, 0.80128205,
                    0.80128205, 0.80128205, 0.7980769 , 0.79647434]

# %%
# create multiple distribution plot of experiment accuracies
sns.set(color_codes=True)
sns.distplot(sub_bow_accs, color='blue', label='BoW', hist=False)
sns.distplot(sub_seq_bow_accs, color='magenta', label='Sequence BoW', hist=False)
sns.distplot(sub_emb_accs, color='red', label='Embeddings', hist=False)
sns.distplot(sub_seq_emb_accs, color='green', label='Sequence embeddings', hist=False)

plt.legend()
plt.title('Validation accuracy distributions')
plt.xlabel('Validation accuracy (%)')
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0.5, 0, 'Validation accuracy (%)')

# %%
# create binary distribution plot of experiment accuracies to compare BoW and average embedding
sns.set(color_codes=True)
sns.distplot(sub_bow_accs, color='skyblue', label='BoW', hist=True)
sns.distplot(sub_emb_accs, color='red', label='Embeddings', hist=True)

plt.legend()
plt.title('Validation accuracy distributions')
plt.xlabel('Validation accuracy \(%\)')
# Out:
# Text(0.5, 0, 'Validation accuracy \\(%\\)')
